# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('movies_metadata.csv')

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df=df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df=df[['title','overview','genres','tagline','vote_average','popularity']]

# %%
df.shape
# Out:
# (45453, 6)

# %%
df.isnull().sum()
# Out:
# title               6
# overview          954
# genres              0
# tagline         25045
# vote_average        6
# popularity          5
# dtype: int64

# %%
df=df.dropna(subset=['title'])

# %%
df.isnull().sum()
# Out:
# title               0
# overview          954
# genres              0
# tagline         25039
# vote_average        0
# popularity          0
# dtype: int64

# %%
df['overview']=df['overview'].fillna('')

# %%
df.iloc[0]['genres']
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
import ast
df['genres'] = df['genres'].apply(lambda x :" ".join([i['name'] for i in ast.literal_eval(x)]))

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                NaN           7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df['tagline']=df['tagline'].fillna('')

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df.isnull().sum()
# Out:
# title           0
# overview        0
# genres          0
# tagline         0
# vote_average    0
# popularity      0
# dtype: int64

# %%
df['tags']=df['overview'] + " "+df['genres']+" "+df['tagline']

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df['tags'][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text):
  #lowercase
  text = str(text).lower()
  #removed the punctuations
  text = re.sub(r'[^a-zA-Z\s]', '', text)

  words = text.split()
  #remove stopwords
  words = [word for word in words if word not in stop_words]

  #lemmatize
  words = [lemmatizer.lemmatize(word) for word in words]

  return " ".join(words)

# %%
df['tags'] = df['tags'].apply(preprocess_text)

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df=df.reset_index(drop=True)

# %%
indices=pd.Series(df.index,index=df['title']).drop_duplicates()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=50000,ngram_range=(1,2),stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['tags'])
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1548114 stored elements and shape (45447, 50000)>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(title, n = 10):
  if title not in indices:
    return ['Movie not found']

  idx = indices[title]
  sim_score = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()
  similar_idx = sim_score.argsort()[::-1][1:n+1]
  return df['title'].iloc[similar_idx]

# %%
recommend('Avatar')
# Out:
# 26547                  Avatar 2
# 13883      The Inhabited Island
# 26553            Thor: Ragnarok
# 43431    Moontrap: Target Earth
# 14119      The Three Musketeers
# 9949         A Trip to the Moon
# 43983       Nightmare City 2035
# 28403    France société anonyme
# 20372                    Désiré
# 28633      Stand by Me Doraemon
# Name: title, dtype: object

# %%
import pickle

pickle.dump(tfidf_matrix,open('tfidf_matrix.pkl','wb'))
pickle.dump(indices,open('indices.pkl','wb'))
df.to_pickle('df.pkl')
pickle.dump(tfidf,open('tfidf.pkl','wb'))

# %%
def get_genres_from_title(movie_title):
  if movie_title not in indices:
    return []

  idx = indices[movie_title]
  genres_string = df['genres'].iloc[idx]
  return genres_string.split()

# %%
def is_relevant(query_movie_title, recommended_movie_title):
  query_genres = set(get_genres_from_title(query_movie_title))
  recommended_genres = set(get_genres_from_title(recommended_movie_title))

  return bool(query_genres.intersection(recommended_genres))

# %%
def calculate_precision_at_k(query_movie_title, k):
  if k == 0:
    return 0.0

  recommended_movies = recommend(query_movie_title, n=k)

  if recommended_movies[0] == 'Movie not found':
    return 0.0

  relevant_recommendations = 0
  for rec_title in recommended_movies:
    if is_relevant(query_movie_title, rec_title):
      relevant_recommendations += 1

  precision_at_k = relevant_recommendations / k
  return precision_at_k

print("Function 'calculate_precision_at_k' defined.")
# Out:
# Function 'calculate_precision_at_k' defined.

# %%
def get_genres_from_title(movie_title):
  if movie_title not in indices:
    return [] # Return an empty list if movie title is not found

  idx = indices[movie_title]
  genres_string = df['genres'].iloc[idx]
  return genres_string.split()

# %%
def recommend(title, n = 10):
  if title not in indices:
    return ['Movie not found']

  idx = indices[title]
  sim_score = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()
  similar_idx = sim_score.argsort()[::-1][1:n+1]
  return df['title'].iloc[similar_idx].tolist()

# %%
def calculate_precision_at_k(query_movie_title, k):
  if k == 0:
    return 0.0

  recommended_movies = recommend(query_movie_title, n=k)

  if not recommended_movies or recommended_movies == ['Movie not found']:
    return 0.0

  relevant_recommendations = 0
  for rec_title in recommended_movies:
    if is_relevant(query_movie_title, rec_title):
      relevant_recommendations += 1

  if len(recommended_movies) == 0:
      return 0.0

  precision_at_k = relevant_recommendations / len(recommended_movies)
  return precision_at_k

# %%
df_unique_titles = df.drop_duplicates(subset=['title'], keep='first').reset_index()
indices = pd.Series(df_unique_titles['index'].values, index=df_unique_titles['title']).drop_duplicates()

# %%
def get_genres_from_title(movie_title):
  if movie_title not in indices:
    return []
  original_idx = indices[movie_title]
  genres_string = df['genres'].iloc[original_idx]
  return genres_string.split()

# %%
def is_relevant(query_movie_title, recommended_movie_title):
  query_genres = set(get_genres_from_title(query_movie_title))
  recommended_genres = set(get_genres_from_title(recommended_movie_title))

  return bool(query_genres.intersection(recommended_genres))

# %%
def recommend(title, n = 10):
  if title not in indices:
    return ['Movie not found']

  original_idx = indices[title]
  sim_score = cosine_similarity(tfidf_matrix[original_idx].reshape(1, -1), tfidf_matrix).flatten()
  similar_idx = sim_score.argsort()[::-1][1:n+1]
  return df['title'].iloc[similar_idx].tolist()

print("Function 'recommend' redefined to return a list.")
# Out:
# Function 'recommend' redefined to return a list.

# %%
def calculate_precision_at_k(query_movie_title, k):
  if k == 0:
    return 0.0

  recommended_movies = recommend(query_movie_title, n=k)

  if not recommended_movies or recommended_movies == ['Movie not found']:
    return 0.0

  relevant_recommendations = 0
  for rec_title in recommended_movies:
    if is_relevant(query_movie_title, rec_title):
      relevant_recommendations += 1

  if len(recommended_movies) == 0:
      return 0.0

  precision_at_k = relevant_recommendations / len(recommended_movies)
  return precision_at_k
# Out:
# Function 'calculate_precision_at_k' redefined for list output.

# %%
import numpy as np

sample_size = 100
sampled_movie_titles = np.random.choice(df['title'].unique(), size=sample_size, replace=False)

precision_scores = []
k_value = 10

for title in sampled_movie_titles:
    precision = calculate_precision_at_k(title, k_value)
    precision_scores.append(precision)

average_precision_at_k = np.mean(precision_scores)

print(f"Average Precision@{k_value}: {average_precision_at_k:.4f}")
# Out:
# Average Precision@10: 0.6780
